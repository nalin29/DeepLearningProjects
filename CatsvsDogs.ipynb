# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg

# %%
train_image_dir = os.getcwd() + '/data/dogs-vs-cats/train'
test_image_dir = os.getcwd() + '/data/dogs-vs-cats/test1'

# %%
train_dog_dir = train_image_dir+'/dogs'
train_cat_dir = train_image_dir+'/cats'

# %%
listDogs = os.listdir(train_dog_dir)
listCats = os.listdir(train_cat_dir)
fig = plt.figure(figsize=(16,16))
index = 16
for i in range(index-16, index, 2):
    img = mpimg.imread(train_dog_dir+'/'+listDogs[i])
    fig.add_subplot(4,4,i+1)
    plt.imshow(img)
    plt.axis('off')
    plt.text(x=0, y=0,s='Dog')
    img = mpimg.imread(train_cat_dir+'/'+listCats[i])
    fig.add_subplot(4,4,i+2)
    plt.imshow(img)
    plt.axis('off')
    plt.text(x=0, y=0,s='Cat')
plt.show()
